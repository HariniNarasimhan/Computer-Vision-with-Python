# %% [markdown]
# # Images with Opencv
#
# **COMPLETE THE TASKS BELOW.**

# %% [markdown]
# #### TASK: Open the *dog_backpack.jpg* image from the DATA folder and display it in the notebook. Make sure to correct for the RGB order.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('../DATA/dog_backpack.jpg') # cv2 takes image in BGR format (Blue Green Red)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)

# %%
plt.imshow(image_rgb)

# %% [markdown]
# #### TASK: Flip the image upside down and display it in the notebook.

# %%
flip_image = cv2.flip(image_rgb,0)
plt.imshow(flip_image)

# %%
flip_image_mirror = cv2.flip(image_rgb,1)
plt.imshow(flip_image_mirror)

# %% [markdown]
# #### TASK: Draw an empty RED rectangle around the dogs face and display the image in the notebook.

# %%
plt.imshow(image_rgb)
plt.title('Original image')
# Out:
# Text(0.5, 1.0, 'Original image')

# %%
drew_image = image_rgb.copy()
cv2.rectangle(drew_image, pt1=(200,350), pt2=(600,700), thickness=5,color=[255,0,0])
plt.imshow(drew_image)

# %% [markdown]
# #### TASK: Draw an empty RED rectangle around the dogs face as filled and display the image in the notebook.

# %%
drew_image = image_rgb.copy()
cv2.rectangle(drew_image, pt1=(200,350), pt2=(600,700), thickness=-1,color=[255,0,0])
plt.imshow(drew_image)

# %% [markdown]
# #### TASK: Draw a BLUE TRIANGLE in the middle of the image. The size and angle is up to you, but it should be a triangle (three sides) in any orientation.

# %%
drew_triangle = image_rgb.copy()
vertices = np.array([[250,700], [400,400], [600,700]])

pts = vertices.reshape((-1,1,2))

# %%
cv2.polylines(drew_triangle,[pts],isClosed=True,color=(0,0,255),thickness=20)
plt.imshow(drew_triangle)

# %% [markdown]
# ### TASK. Can you figure our how to fill in this triangle? It requires a different function. See if you can use google search to find it.

# %%
draw_tri=image_rgb.copy()
cv2.fillPoly(draw_tri,[pts],color=[0,0,255])
plt.imshow(draw_tri)

# %% [markdown]
# #### TASK: (NOTE: YOU WILL NEED TO RUN THIS AS A SCRIPT). Create a script that opens the picture and allows you to draw empty red circles whever you click the RIGHT MOUSE BUTTON DOWN.

# %%
def draw_circle(event,x,y,flags,param):
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img,(x,y),50,(0,255,0),5)

# Create a black image
image = cv2.imread('../DATA/dog_backpack.jpg') # cv2 takes image in BGR format (Blue Green Red)
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 

# This names the window so we can reference it 
cv2.namedWindow(winname='my_drawing')
# Connects the mouse button to our callback function
cv2.setMouseCallback('my_drawing',draw_circle)

while True: #Runs forever until we break with Esc key on keyboard
    # Shows the image window
    cv2.imshow('my_drawing',img)
    # EXPLANATION FOR THIS LINE OF CODE:
    # https://stackoverflow.com/questions/35372700/whats-0xff-for-in-cv2-waitkey1/39201163
    if cv2.waitKey(20) & 0xFF == 27:
        break
# Once script is done, its usually good practice to call this line
# It closes all windows (just in case you have multiple windows called)
cv2.destroyAllWindows()

# %% [markdown]
# #### TASK: Connecting a Function for Drawing - To draw a rectangle by dragging

# %%
# Create a function based on a CV2 Event (Left button click)
drawing = False # True if mouse is pressed
ix,iy = -1,-1

# mouse callback function
def draw_rectangle(event,x,y,flags,param):
    global ix,iy,drawing,mode

    if event == cv2.EVENT_LBUTTONDOWN:
        # When you click DOWN with left mouse button drawing is set to True
        drawing = True
        # Then we take note of where that mouse was located
        ix,iy = x,y

    elif event == cv2.EVENT_MOUSEMOVE:
        # Now the mouse is moving
        if drawing == True:
            # If drawing is True, it means you've already clicked on the left mouse button
            # We draw a rectangle from the previous position to the x,y where the mouse is
            cv2.rectangle(img,(ix,iy),(x,y),(0,0,255),-1)
           

    elif event == cv2.EVENT_LBUTTONUP:
        # Once you lift the mouse button, drawing is False
        drawing = False
        # we complete the rectangle.
        cv2.rectangle(img,(ix,iy),(x,y),(0,0,255),-1)
        
        

# Create a black image
image = cv2.imread('../DATA/dog_backpack.jpg') # cv2 takes image in BGR format (Blue Green Red)
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 

# This names the window so we can reference it 
cv2.namedWindow(winname='my_drawing')
# Connects the mouse button to our callback function
cv2.setMouseCallback('my_drawing',draw_rectangle)

while True: #Runs forever until we break with Esc key on keyboard
    # Shows the image window
    cv2.imshow('my_drawing',img)
    # EXPLANATION FOR THIS LINE OF CODE:
    # https://stackoverflow.com/questions/35372700/whats-0xff-for-in-cv2-waitkey1/39201163
    
    # CHECK TO SEE IF ESC WAS PRESSED ON KEYBOARD
    if cv2.waitKey(1) & 0xFF == 27:
        break
# Once script is done, its usually good practice to call this line
# It closes all windows (just in case you have multiple windows called)
cv2.destroyAllWindows()

# %% [markdown]
# ## Great Job!
